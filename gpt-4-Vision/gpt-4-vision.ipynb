# %% [markdown]
# GPT-4 Vision

# %%
# Show data/ingredients.png image below
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open('../data/ingredients.jpeg')
plt.imshow(img)
plt.show()

# %%
# import os
# import requests
# import base64
# from dotenv import load_dotenv
# load_dotenv()

# # Configuration
# GPT4V_KEY = os.getenv('AZURE_OPENAI_KEY')
# print(GPT4V_KEY)
# IMAGE_PATH = '../data/ingredients.jpeg'
# encoded_image = base64.b64encode(open(IMAGE_PATH, 'rb').read()).decode('ascii')
# headers = {
#     "Content-Type": "application/json",
#     "apikey": GPT4V_KEY,
# }

# # Payload for the request
# payload = {
#   "messages": [
#     {
#       "role": "system",
#       "content": [
#         {
#           "type": "text",
#           "text": "You are an AI assistant that helps people find information."
#         }
#       ]
#     },
#     {
#       "role": "user",
#       "content": [
#         {
#           "type": "image_url",
#           "image_url": {
#             "url": f"data:image/jpeg;base64,{encoded_image}"
#           }
#         },
#         {
#           "type": "text",
#           "text": "이 사진에 대해서 설명해줘."
#         }
#       ]
#     }
#   ],
#   "temperature": 0.7,
#   "top_p": 0.95,
#   "max_tokens": 800
# }

# GPT4V_ENDPOINT = "https://teamgptaoai.openai.azure.com/openai/deployments/gpt-4-vision/chat/completions?api-version=2024-02-15-preview"


# # Send request
# try:
#     response = requests.post(GPT4V_ENDPOINT, headers=headers, json=payload)
#     response.raise_for_status()  # Will raise an HTTPError if the HTTP request returned an unsuccessful status code
# except requests.RequestException as e:
#     raise SystemExit(f"Failed to make the request. Error: {e}")

# # Handle the response as needed (e.g., print or process)
# print(response.json()['choices'][0]['message']['content'])

# %%
import os
import requests
import base64

# Configuration
GPT4V_KEY = os.getenv('AZURE_OPENAI_KEY')
IMAGE_PATH = "../data/ingredients.jpeg"
encoded_image = base64.b64encode(open(IMAGE_PATH, 'rb').read()).decode('ascii')
headers = {
    "Content-Type": "application/json",
    "api-key": GPT4V_KEY,
}

# Payload for the request
payload = {
  "messages": [
    {
      "role": "system",
      "content": [
        {
          "type": "text",
          "text": "You are an AI assistant that helps people find information."
        }
      ]
    },
    {
      "role": "user",
      "content": [
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{encoded_image}"
          }
        },
        {
          "type": "text",
          "text": "이 사진에 대해서 설명해줘."
        }
      ]
    }
  ],
  "temperature": 0.7,
  "top_p": 0.95,
  "max_tokens": 800
}

GPT4V_ENDPOINT = "https://teamgptaoai.openai.azure.com/openai/deployments/gpt-4-vision/chat/completions?api-version=2024-02-15-preview"

# Send request
try:
    response = requests.post(GPT4V_ENDPOINT, headers=headers, json=payload)
    response.raise_for_status()  # Will raise an HTTPError if the HTTP request returned an unsuccessful status code
except requests.RequestException as e:
    raise SystemExit(f"Failed to make the request. Error: {e}")

# Handle the response as needed (e.g., print or process)
print(response.json()['choices'][0]['message']['content'])
# Out:
# 이 사진은 다양한 요리 재료들이 나누어 담겨 있는 모습을 보여줍니다. 왼쪽 상단에서부터 시계 방향으로 설명하자면:
#
# 1. 노란색 액체가 담긴 작은 그릇은 올리브 오일로 보입니다.
# 2. 밝은 노랑색의 액체가 담긴 큰 그릇은 잘 풀어진 달걀 물입니다.
# 3. 녹색 완두콩과 주황색 당근이 섞여 있는 그릇은 다진 야채로, 볶음 요리나 오믈렛에 넣을 수 있는 재료입니다.
# 4. 잘게 다진 마늘은 강한 향을 내는 조미료입니다.
# 5. 간장을 담은 작은 그릇은 소스로 사용할 수 있습니다.
# 6. 잘게 썬 파의 그릇은 신선한 향을 내는 데 사용될 수 있습니다.
# 7. 백색의 콩나물이 담긴 그릇은 바삭한 식감을 제공합니다.
# 8. 가운데 큰 그릇에는 밥이 담겨 있어, 볶음밥의 주재료로 사용될 수 있습니다.
# 9. 마지막으로, 찢어진 닭 가슴살이 담긴 그릇은 단백질을 제공하며 볶음 요리에 좋은 재료입니다.
#
# 이 재료들을 보아하니, 볶음밥이나 오믈렛 등 다양한 요리를 준비하기 위한 재료로 보입니다.
